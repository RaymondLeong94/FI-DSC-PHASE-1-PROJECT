# %%
import pandas as pd
import numpy as np
import sqlite3 
import seaborn as sns
from matplotlib import pyplot as plt
from scipy import stats
from pandasql import sqldf
pd.set_option('display.float_format', '{:.2f}'.format)

# %%
import pandas as pd
import numpy as np
import sqlite3 
import seaborn as sns
from matplotlib import pyplot as plt
from scipy import stats
from pandasql import sqldf
pd.set_option('display.float_format', '{:.2f}'.format)

# %%
data = pd.read_csv("bom.movie_gross.csv.gz")

# %%
data.head()
# Out:
#                                          title studio  domestic_gross  \
# 0                                  Toy Story 3     BV    415000000.00
# 1                   Alice in Wonderland (2010)     BV    334200000.00
# 2  Harry Potter and the Deathly Hallows Part 1     WB    296000000.00
# 3                                    Inception     WB    292600000.00
# 4                          Shrek Forever After   P/DW    238700000.00
#
#   foreign_gross  year
# 0     652000000  2010
# 1     691300000  2010
# 2     664300000  2010
# 3     535700000  2010
# 4     513900000  2010

# %%
print(list(data.columns))
# Out:
# ['title', 'studio', 'domestic_gross', 'foreign_gross', 'year']

# %%
data.isnull()
# Out:
#       title  studio  domestic_gross  foreign_gross   year
# 0     False   False           False          False  False
# 1     False   False           False          False  False
# 2     False   False           False          False  False
# 3     False   False           False          False  False
# 4     False   False           False          False  False
# ...     ...     ...             ...            ...    ...
# 3382  False   False           False           True  False
# 3383  False   False           False           True  False
# 3384  False   False           False           True  False
# 3385  False   False           False           True  False
# 3386  False   False           False           True  False
#
# [3387 rows x 5 columns]

# %%
data["foreign_gross"] = data["foreign_gross"].fillna(0)
data["domestic_gross"] = data["domestic_gross"].fillna(0)

# %%
data.isnull()
# Out:
#       title  studio  domestic_gross  foreign_gross   year
# 0     False   False           False          False  False
# 1     False   False           False          False  False
# 2     False   False           False          False  False
# 3     False   False           False          False  False
# 4     False   False           False          False  False
# ...     ...     ...             ...            ...    ...
# 3382  False   False           False          False  False
# 3383  False   False           False          False  False
# 3384  False   False           False          False  False
# 3385  False   False           False          False  False
# 3386  False   False           False          False  False
#
# [3387 rows x 5 columns]

# %%
data["foreign_gross"] = pd.to_numeric(data["foreign_gross"], errors = 'coerce')

# %%
#data["total_gross"] = data["domestic_gross"] + data["foreign_gross"]

# %%
#data["total_gross"] = pd.to_numeric(data["total_gross"], downcast='integer')

# %%
#data["total_gross"].fillna(0)

# %%
#data["total_gross"] = data["total_gross"].astype(str).apply(lambda x: x.replace('.0',''))

# %%
data["foreign_gross"]= data["foreign_gross"].astype(str).apply(lambda x: x.replace('.0',''))
data["domestic_gross"]= data["domestic_gross"].astype(str).apply(lambda x: x.replace('.0',''))

# %%
data['domestic_gross']
# Out:
# 0       415000000
# 1       334200000
# 2       296000000
# 3       292600000
# 4       238700000
#           ...
# 3382         6200
# 3383         4800
# 3384         2500
# 3385         2400
# 3386         1700
# Name: domestic_gross, Length: 3387, dtype: object

# %%
data["foreign_gross"]= data["foreign_gross"].astype(str).apply(lambda x: x.replace('.0',''))
#data["total_gross"] = pd.to_numeric(data["total_gross"], downcast='integer')

# %%
data["foreign_gross"]= data["foreign_gross"].astype(str).apply(lambda x: x.replace('.0',''))
data["domestic_gross"]= data["domestic_gross"].astype(str).apply(lambda x: x.replace('.0',''))

# %%
data["foreign_gross"] = pd.to_numeric(data["foreign_gross"], errors = 'coerce')

# %%
data["domestic_gross"] = pd.to_numeric(data["domestic_gross"], errors = 'coerce')

# %%
#data["total_gross"] = pd.to_numeric(data["total_gross"], downcast='integer')

# %%
data["foreign_gross"] = pd.to_numeric(data["foreign_gross"], downcast='integer')

# %%
data
# Out:
#                                             title      studio  domestic_gross  \
# 0                                     Toy Story 3          BV       415000000
# 1                      Alice in Wonderland (2010)          BV       334200000
# 2     Harry Potter and the Deathly Hallows Part 1          WB       296000000
# 3                                       Inception          WB       292600000
# 4                             Shrek Forever After        P/DW       238700000
# ...                                           ...         ...             ...
# 3382                                    The Quake       Magn.            6200
# 3383                  Edward II (2018 re-release)          FM            4800
# 3384                                     El Pacto        Sony            2500
# 3385                                     The Swan  Synergetic            2400
# 3386                            An Actor Prepares       Grav.            1700
#
#       foreign_gross  year
# ...

# %%
data["total_gross"] = data["domestic_gross"] + data["foreign_gross"]

# %%
data["total_gross"] = pd.to_numeric(data["total_gross"], downcast='integer')

# %%
data["total_gross"] = data["total_gross"].astype(str).apply(lambda x: x.replace('.0',''))

# %%
data
# Out:
#                                             title      studio  domestic_gross  \
# 0                                     Toy Story 3          BV       415000000
# 1                      Alice in Wonderland (2010)          BV       334200000
# 2     Harry Potter and the Deathly Hallows Part 1          WB       296000000
# 3                                       Inception          WB       292600000
# 4                             Shrek Forever After        P/DW       238700000
# ...                                           ...         ...             ...
# 3382                                    The Quake       Magn.            6200
# 3383                  Edward II (2018 re-release)          FM            4800
# 3384                                     El Pacto        Sony            2500
# 3385                                     The Swan  Synergetic            2400
# 3386                            An Actor Prepares       Grav.            1700
#
# ...

# %%
#data["dom_over_total"] = data["domestic_gross"].div(data["total_gross"].values)
data["total_gross"] = pd.to_numeric(data["total_gross"], errors = 'coerce')

# %%
data["total_gross"]= pd.to_numeric(data["total_gross"], errors = 'coerce')

# %%
data["dom_over_total"] = data["domestic_gross"].div(data["total_gross"].values)

# %%
data
# Out:
#                                             title      studio  domestic_gross  \
# 0                                     Toy Story 3          BV       415000000
# 1                      Alice in Wonderland (2010)          BV       334200000
# 2     Harry Potter and the Deathly Hallows Part 1          WB       296000000
# 3                                       Inception          WB       292600000
# 4                             Shrek Forever After        P/DW       238700000
# ...                                           ...         ...             ...
# 3382                                    The Quake       Magn.            6200
# 3383                  Edward II (2018 re-release)          FM            4800
# 3384                                     El Pacto        Sony            2500
# 3385                                     The Swan  Synergetic            2400
# 3386                            An Actor Prepares       Grav.            1700
#
# ...

# %%
data["dom_over_total_percentage"] = data["dom_over_total"].apply(lambda x: x*100)

# %%
data
# Out:
#                                             title      studio  domestic_gross  \
# 0                                     Toy Story 3          BV       415000000
# 1                      Alice in Wonderland (2010)          BV       334200000
# 2     Harry Potter and the Deathly Hallows Part 1          WB       296000000
# 3                                       Inception          WB       292600000
# 4                             Shrek Forever After        P/DW       238700000
# ...                                           ...         ...             ...
# 3382                                    The Quake       Magn.            6200
# 3383                  Edward II (2018 re-release)          FM            4800
# 3384                                     El Pacto        Sony            2500
# 3385                                     The Swan  Synergetic            2400
# 3386                            An Actor Prepares       Grav.            1700
#
# ...

# %%
data1 = pd.read_csv("tmdb.movies.csv.gz")
data1
# Out:
#        Unnamed: 0            genre_ids      id original_language  \
# 0               0      [12, 14, 10751]   12444                en
# 1               1  [14, 12, 16, 10751]   10191                en
# 2               2        [12, 28, 878]   10138                en
# 3               3      [16, 35, 10751]     862                en
# 4               4        [28, 878, 12]   27205                en
# ...           ...                  ...     ...               ...
# 26512       26512             [27, 18]  488143                en
# 26513       26513             [18, 53]  485975                en
# 26514       26514         [14, 28, 12]  381231                en
# 26515       26515      [10751, 12, 28]  366854                en
# 26516       26516             [53, 27]  309885                en
#
#                                      original_title  popularity release_date  \
# 0      Harry Potter and the Deathly Hallows: Part 1       33.53   2010-11-19
# ...

# %%
please_work = pd.merge(data, data1, on="title")

# %%
please_work
# Out:
#                            title  studio  domestic_gross  foreign_gross  year  \
# 0                    Toy Story 3      BV       415000000   652000000.00  2010
# 1                      Inception      WB       292600000   535700000.00  2010
# 2            Shrek Forever After    P/DW       238700000   513900000.00  2010
# 3     The Twilight Saga: Eclipse    Sum.       300500000   398000000.00  2010
# 4                     Iron Man 2    Par.       312400000   311500000.00  2010
# ...                          ...     ...             ...            ...   ...
# 2698                  The Escape     IFC           14000           0.00  2018
# 2699                  The Escape     IFC           14000           0.00  2018
# 2700                    Souvenir  Strand           11400           0.00  2018
# 2701                   The Quake   Magn.            6200           0.00  2018
# 2702           An Actor Prepares   Grav.            1700           0.00  2018
#
# ...

# %%
#plt.scatter(please_work["total_gross"], please_work["vote_average"])
#dont use this
please_work.iloc[0:10]
# Out:
#                                                title studio  domestic_gross  \
# 0                                        Toy Story 3     BV       415000000
# 1                                          Inception     WB       292600000
# 2                                Shrek Forever After   P/DW       238700000
# 3                         The Twilight Saga: Eclipse   Sum.       300500000
# 4                                         Iron Man 2   Par.       312400000
# 5                                            Tangled     BV       200800000
# 6                                      Despicable Me   Uni.       251500000
# 7                           How to Train Your Dragon   P/DW       217600000
# 8  The Chronicles of Narnia: The Voyage of the Da...    Fox       104400000
# 9                                  The King's Speech  Wein.       135500000
#
#    foreign_gross  year   total_gross  dom_over_total  \
# 0   652000000.00  2010 1067000000.00            0.39
# ...

# %%
#= vote avg is indepenent of the total_gross -> is this a really good predictor for the succesfullness of the movie?

# %%
#please_work

# %%
#Please_work= please_work.groupby("studio").count()
#please_work

# %%
#please_work_2 = please_work['studio','total_gross']

# %%
data
# Out:
#                                             title      studio  domestic_gross  \
# 0                                     Toy Story 3          BV       415000000
# 1                      Alice in Wonderland (2010)          BV       334200000
# 2     Harry Potter and the Deathly Hallows Part 1          WB       296000000
# 3                                       Inception          WB       292600000
# 4                             Shrek Forever After        P/DW       238700000
# ...                                           ...         ...             ...
# 3382                                    The Quake       Magn.            6200
# 3383                  Edward II (2018 re-release)          FM            4800
# 3384                                     El Pacto        Sony            2500
# 3385                                     The Swan  Synergetic            2400
# 3386                            An Actor Prepares       Grav.            1700
#
# ...

# %%
data1
# Out:
#        Unnamed: 0            genre_ids      id original_language  \
# 0               0      [12, 14, 10751]   12444                en
# 1               1  [14, 12, 16, 10751]   10191                en
# 2               2        [12, 28, 878]   10138                en
# 3               3      [16, 35, 10751]     862                en
# 4               4        [28, 878, 12]   27205                en
# ...           ...                  ...     ...               ...
# 26512       26512             [27, 18]  488143                en
# 26513       26513             [18, 53]  485975                en
# 26514       26514         [14, 28, 12]  381231                en
# 26515       26515      [10751, 12, 28]  366854                en
# 26516       26516             [53, 27]  309885                en
#
#                                      original_title  popularity release_date  \
# 0      Harry Potter and the Deathly Hallows: Part 1       33.53   2010-11-19
# ...

# %%
data2 = pd.read_csv("tn.movie_budgets.csv.gz")
data2 = data2.rename(columns={"movie": "title"})
data2
# Out:
#       id  release_date                                        title  \
# 0      1  Dec 18, 2009                                       Avatar
# 1      2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2      3   Jun 7, 2019                                 Dark Phoenix
# 3      4   May 1, 2015                      Avengers: Age of Ultron
# 4      5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
# ...   ..           ...                                          ...
# 5777  78  Dec 31, 2018                                       Red 11
# 5778  79   Apr 2, 1999                                    Following
# 5779  80  Jul 13, 2005                Return to the Land of Wonders
# 5780  81  Sep 29, 2015                         A Plague So Pleasant
# 5781  82   Aug 5, 2005                            My Date With Drew
#
#      production_budget domestic_gross worldwide_gross
# 0         $425,000,000   $760,507,625  $2,776,345,279
# ...

# %%
final = pd.merge(please_work, data2, on="title")
#please_work = pd.merge(data, data1, on="title")

# %%
final
# Out:
#                            title studio  domestic_gross_x  foreign_gross  \
# 0                    Toy Story 3     BV         415000000   652000000.00
# 1                      Inception     WB         292600000   535700000.00
# 2            Shrek Forever After   P/DW         238700000   513900000.00
# 3     The Twilight Saga: Eclipse   Sum.         300500000   398000000.00
# 4                     Iron Man 2   Par.         312400000   311500000.00
# ...                          ...    ...               ...            ...
# 1390  Bilal: A New Breed of Hero     VE            491000     1700000.00
# 1391                       Mandy    RLJ           1200000           0.00
# 1392                       Mandy    RLJ           1200000           0.00
# 1393                Lean on Pete    A24           1200000           0.00
# 1394                Lean on Pete    A24           1200000           0.00
#
#       year   total_gross  dom_over_total  dom_over_total_percentage  \
# ...

# %%
final["production_budget"] = final["production_budget"].astype(str).apply(lambda x: x.replace("," ,''))
final["production_budget"] = final["production_budget"].astype(str).apply(lambda x: x.replace('$',''))
final
#data["foreign_gross"] = pd.to_numeric(data["foreign_gross"], errors = 'coerce')
# Out:
#                            title studio  domestic_gross_x  foreign_gross  \
# 0                    Toy Story 3     BV         415000000   652000000.00
# 1                      Inception     WB         292600000   535700000.00
# 2            Shrek Forever After   P/DW         238700000   513900000.00
# 3     The Twilight Saga: Eclipse   Sum.         300500000   398000000.00
# 4                     Iron Man 2   Par.         312400000   311500000.00
# ...                          ...    ...               ...            ...
# 1390  Bilal: A New Breed of Hero     VE            491000     1700000.00
# 1391                       Mandy    RLJ           1200000           0.00
# 1392                       Mandy    RLJ           1200000           0.00
# 1393                Lean on Pete    A24           1200000           0.00
# 1394                Lean on Pete    A24           1200000           0.00
#
#       year   total_gross  dom_over_total  dom_over_total_percentage  \
# ...

# %%
final["production_budget"] = pd.to_numeric(final["production_budget"], errors = 'coerce')
final["Actualtotalgrossfinal"] = final["total_gross"] - final["production_budget"]
final
# Out:
#                            title studio  domestic_gross_x  foreign_gross  \
# 0                    Toy Story 3     BV         415000000   652000000.00
# 1                      Inception     WB         292600000   535700000.00
# 2            Shrek Forever After   P/DW         238700000   513900000.00
# 3     The Twilight Saga: Eclipse   Sum.         300500000   398000000.00
# 4                     Iron Man 2   Par.         312400000   311500000.00
# ...                          ...    ...               ...            ...
# 1390  Bilal: A New Breed of Hero     VE            491000     1700000.00
# 1391                       Mandy    RLJ           1200000           0.00
# 1392                       Mandy    RLJ           1200000           0.00
# 1393                Lean on Pete    A24           1200000           0.00
# 1394                Lean on Pete    A24           1200000           0.00
#
#       year   total_gross  dom_over_total  dom_over_total_percentage  \
# ...

# %%
ConnectiontoDF = sqlite3.connect("im.db")
cur_IMDB = ConnectiontoDF.cursor()
cur_IMDB.execute("""SELECT name FROM sqlite_master WHERE type = 'table';""")
IMBD_tables = cur_IMDB.fetchall()
IMBD_tables
# Out:
# [('movie_basics',),
#  ('directors',),
#  ('known_for',),
#  ('movie_akas',),
#  ('movie_ratings',),
#  ('persons',),
#  ('principals',),
#  ('writers',)]

# %%
cur_IMDB.execute("""SELECT * FROM movie_basics;""")
cur_IMDB.fetchall()
Whatisinhere1 = """
SELECT *
FROM movie_basics
;
"""
cur_IMDB.execute(Whatisinhere1).fetchall()
df12 = pd.DataFrame(cur_IMDB.execute(Whatisinhere1).fetchall())
from matplotlib.pyplot import figure

# %%
x12 = df12[4].fillna(value=df12[4].mean(), inplace=True)

# %%
x12 = df12.drop([2], axis=1)
x12
# Out:
#                 0                                            1     3      4  \
# 0       tt0063540                                    Sunghursh  2013 175.00
# 1       tt0066787              One Day Before the Rainy Season  2019 114.00
# 2       tt0069049                   The Other Side of the Wind  2018 122.00
# 3       tt0069204                              Sabse Bada Sukh  2018  86.19
# 4       tt0100275                     The Wandering Soap Opera  2017  80.00
# ...           ...                                          ...   ...    ...
# 146139  tt9916538                          Kuambil Lagi Hatiku  2019 123.00
# 146140  tt9916622  Rodolpho Teóphilo - O Legado de um Pioneiro  2015  86.19
# 146141  tt9916706                              Dankyavar Danka  2013  86.19
# 146142  tt9916730                                       6 Gunn  2017 116.00
# 146143  tt9916754               Chico Albuquerque - Revelações  2013  86.19
#
#                            5
# ...

# %%
x12.rename(columns = {0:"movie_id", 1:"title", 3:"year", 4:"runtime", 5:"genres"}, inplace = True)

# %%
x12
# Out:
#          movie_id                                        title  year  runtime  \
# 0       tt0063540                                    Sunghursh  2013   175.00
# 1       tt0066787              One Day Before the Rainy Season  2019   114.00
# 2       tt0069049                   The Other Side of the Wind  2018   122.00
# 3       tt0069204                              Sabse Bada Sukh  2018    86.19
# 4       tt0100275                     The Wandering Soap Opera  2017    80.00
# ...           ...                                          ...   ...      ...
# 146139  tt9916538                          Kuambil Lagi Hatiku  2019   123.00
# 146140  tt9916622  Rodolpho Teóphilo - O Legado de um Pioneiro  2015    86.19
# 146141  tt9916706                              Dankyavar Danka  2013    86.19
# 146142  tt9916730                                       6 Gunn  2017   116.00
# 146143  tt9916754               Chico Albuquerque - Revelações  2013    86.19
#
#                       genres
# ...

# %%
final
# Out:
#                            title studio  domestic_gross_x  foreign_gross  \
# 0                    Toy Story 3     BV         415000000   652000000.00
# 1                      Inception     WB         292600000   535700000.00
# 2            Shrek Forever After   P/DW         238700000   513900000.00
# 3     The Twilight Saga: Eclipse   Sum.         300500000   398000000.00
# 4                     Iron Man 2   Par.         312400000   311500000.00
# ...                          ...    ...               ...            ...
# 1390  Bilal: A New Breed of Hero     VE            491000     1700000.00
# 1391                       Mandy    RLJ           1200000           0.00
# 1392                       Mandy    RLJ           1200000           0.00
# 1393                Lean on Pete    A24           1200000           0.00
# 1394                Lean on Pete    A24           1200000           0.00
#
#       year   total_gross  dom_over_total  dom_over_total_percentage  \
# ...

# %%
fina2l = pd.merge(final, x12, on="title")
fina2l
# Out:
#                            title studio  domestic_gross_x  foreign_gross  \
# 0                    Toy Story 3     BV         415000000   652000000.00
# 1                      Inception     WB         292600000   535700000.00
# 2            Shrek Forever After   P/DW         238700000   513900000.00
# 3     The Twilight Saga: Eclipse   Sum.         300500000   398000000.00
# 4                     Iron Man 2   Par.         312400000   311500000.00
# ...                          ...    ...               ...            ...
# 2092                       Mandy    RLJ           1200000           0.00
# 2093                       Mandy    RLJ           1200000           0.00
# 2094                       Mandy    RLJ           1200000           0.00
# 2095                Lean on Pete    A24           1200000           0.00
# 2096                Lean on Pete    A24           1200000           0.00
#
#       year_x   total_gross  dom_over_total  dom_over_total_percentage  \
# ...

# %%
fina2l.drop_duplicates(subset=["title"])
fina2l.sort_values("Actualtotalgrossfinal")
# Out:
#                         title studio  domestic_gross_x  foreign_gross  year_x  \
# 376           Mars Needs Moms     BV          21400000    17600000.00    2011
# 1686                Evolution    IFC             24800           0.00    2016
# 1687                Evolution    IFC             24800           0.00    2016
# 173      The Nutcracker in 3D   Free            195000    16000000.00    2010
# 1801           Monster Trucks   Par.          33400000    31100000.00    2017
# ...                       ...    ...               ...            ...     ...
# 1927            Black Panther     BV         700100000   646900000.00    2018
# 1074           Jurassic World   Uni.         652300000            nan    2015
# 1075                Furious 7   Uni.         353000000            nan    2015
# 1689  The Fate of the Furious   Uni.         226000000            nan    2017
# 1926   Avengers: Infinity War     BV         678800000            nan    2018
#
# ...

# %%
fina2l.dropna()
# Out:
#                            title studio  domestic_gross_x  foreign_gross  \
# 0                    Toy Story 3     BV         415000000   652000000.00
# 1                      Inception     WB         292600000   535700000.00
# 2            Shrek Forever After   P/DW         238700000   513900000.00
# 3     The Twilight Saga: Eclipse   Sum.         300500000   398000000.00
# 4                     Iron Man 2   Par.         312400000   311500000.00
# ...                          ...    ...               ...            ...
# 2092                       Mandy    RLJ           1200000           0.00
# 2093                       Mandy    RLJ           1200000           0.00
# 2094                       Mandy    RLJ           1200000           0.00
# 2095                Lean on Pete    A24           1200000           0.00
# 2096                Lean on Pete    A24           1200000           0.00
#
#       year_x   total_gross  dom_over_total  dom_over_total_percentage  \
# ...
