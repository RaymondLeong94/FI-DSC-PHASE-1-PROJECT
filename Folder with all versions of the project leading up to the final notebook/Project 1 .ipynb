# %%
import pandas as pd
import numpy as np
import sqlite3

# %%
ConnectiontoDF = sqlite3.connect("im.db") 


#https://github.com/learn-co-curriculum/dsc-selecting-data


print("Data type:", type(ConnectiontoDF))
print("Uncommitted changes:", ConnectiontoDF.in_transaction)
print("Total changes:", ConnectiontoDF.total_changes)
# Out:
# Data type: <class 'sqlite3.Connection'>
# Uncommitted changes: False
# Total changes: 0

# %%
cur = ConnectiontoDF.cursor()

# %%
type(cur)
# Out:
# sqlite3.Cursor

# %%
cur.execute("""SELECT name FROM sqlite_master WHERE type = 'table';""")
table_names = cur.fetchall()
table_names
# Out:
# [('movie_basics',),
#  ('directors',),
#  ('known_for',),
#  ('movie_akas',),
#  ('movie_ratings',),
#  ('persons',),
#  ('principals',),
#  ('writers',)]

# %%
#NTS:  find a loop fx(?) for this to iterate through all and create data frames to explore data 



#cur.execute("""SELECT * FROM persons LIMIT 10;""")
#cur.fetchall()
Whatisinhere1 = """
SELECT *
FROM movie_basics
LIMIT 5
;
"""
#cur.execute(Whatisinhere1).fetchall()
#df1 = pd.DataFrame(cur.execute(Whatisinhere1).fetchall())



Whatisinhere2 = """
SELECT *
FROM directors
LIMIT 5
;
"""
df2 = pd.DataFrame(cur.execute(Whatisinhere2).fetchall())
#df2 = first name last name/ two cols 

Whatisinhere3 = """
SELECT *
FROM known_for 
LIMIT 5
;
"""
#df3 = pd.DataFrame(cur.execute(Whatisinhere3).fetchall())
#df3 !??!?!?!? 


Whatisinhere4 = """
SELECT *
FROM movie_akas
LIMIT 5
;
"""
#df4 = pd.DataFrame(cur.execute(Whatisinhere4).fetchall())
#df4 possible join with first nonindex col = movie namem, alternate title, country, subtiltes?, what and what and the last row is just 0s




Whatisinhere5 = """
SELECT *
FROM movie_ratings
LIMIT 5
;
"""
#df5 = pd.DataFrame(cur.execute(Whatisinhere5).fetchall())
#df5 = rating?>!? find the name of the columns 



Whatisinhere6 = """
SELECT *
FROM persons
LIMIT 10
;
"""
df6 = pd.DataFrame(cur.execute(Whatisinhere6).fetchall())
df6  


Whatisinhere7 = """
SELECT *
FROM principals
LIMIT 10
;
"""
df7 = pd.read_sql(Whatisinhere7, ConnectiontoDF)
df7

Whatisinhere8 = """
SELECT * 
FROM writers
LIMIT 10
;
"""
df2
#df8 = pd.DataFrame(cur.execute(Whatisinhere8).fetchall())
#df8
# Out:
#            0          1
# 0  tt0285252  nm0899854
# 1  tt0462036  nm1940585
# 2  tt0835418  nm0151540
# 3  tt0835418  nm0151540
# 4  tt0878654  nm0089502

# %%
#Whatisinhere1 = """
#SELECT movie_id, primary_title, genres
#FROM movie_basics
#LIMIT 5
#;
#"""
#Whatisinhere1 = """
#SELECT movie_id, primary_title, genres
#FROM movie_basics
#ORDER BY creditLimit DESC
#LIMIT 5
#;
#"""

#cur.execute(Whatisinhere1).fetchall()
df1 = pd.read_sql(Whatisinhere1, ConnectiontoDF)
df1
#break strings -> multiple rows w/ each action crime and drama
#convert to list 
#pass it into
#pd.explode this method was given to me by matt carr
# Out:
#     movie_id                    primary_title              original_title  \
# 0  tt0063540                        Sunghursh                   Sunghursh
# 1  tt0066787  One Day Before the Rainy Season             Ashad Ka Ek Din
# 2  tt0069049       The Other Side of the Wind  The Other Side of the Wind
# 3  tt0069204                  Sabse Bada Sukh             Sabse Bada Sukh
# 4  tt0100275         The Wandering Soap Opera       La Telenovela Errante
#
#    start_year  runtime_minutes                genres
# 0        2013            175.0    Action,Crime,Drama
# 1        2019            114.0       Biography,Drama
# 2        2018            122.0                 Drama
# 3        2018              NaN          Comedy,Drama
# 4        2017             80.0  Comedy,Drama,Fantasy

# %%
#importing diff files 
mns

#df["total"] =  data["domestic_gross"].replace(np.nan, 0) + data["foreign_gross"].replace(np.nan, 0)
#df["total"]
#data.columns
#data.iloc[0:3]
#specific panda methods recommended. na.sum, fillna
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-25d8db489474> in <module>
#       1 #importing diff files
# ----> 2 mns
#       3
#       4 #df["total"] =  data["domestic_gross"].replace(np.nan, 0) + data["foreign_gross"].replace(np.nan, 0)
#       5 #df["total"]
#
# NameError: name 'mns' is not defined

# %%
data1 = pd.read_csv("tmdb.movies.csv.gz")
data1.head(20)

#transform genre_ids as many columns as needed
# Out:
#     Unnamed: 0                 genre_ids     id original_language  \
# 0            0           [12, 14, 10751]  12444                en
# 1            1       [14, 12, 16, 10751]  10191                en
# 2            2             [12, 28, 878]  10138                en
# 3            3           [16, 35, 10751]    862                en
# 4            4             [28, 878, 12]  27205                en
# 5            5           [12, 14, 10751]  32657                en
# 6            6         [28, 12, 14, 878]  19995                en
# 7            7           [16, 10751, 35]  10193                en
# 8            8           [16, 10751, 35]  20352                en
# 9            9  [16, 28, 35, 10751, 878]  38055                en
# 10          10           [16, 35, 10751]    863                en
# 11          11           [10751, 14, 12]  12155                en
# 12          12              [53, 12, 28]  27578                en
# ...

# %%
 data3 = pd.read_csv("tn.movie_budgets.csv.gz")
complex_query = """
SELECT *
FROM data3
WHERE (production_budget >= 420,000,000)
ORDER BY production_budget
LIMIT 15
;"""
df = pd.read_sql(complex_query, ConnectiontoDF)
df
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~\anaconda3\envs\learn-env\lib\site-packages\pandas\io\sql.py in execute(self, *args, **kwargs)
#    1680         try:
# -> 1681             cur.execute(*args, **kwargs)
#    1682             return cur
#
# OperationalError: no such table: data3
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# <ipython-input-10-1fc6d046f856> in <module>
#       7 LIMIT 15
#       8 ;"""
# ----> 9 df = pd.read_sql(complex_query, ConnectiontoDF)
#      10 df
#
# ~\anaconda3\envs\learn-env\lib\site-packages\pandas\io\sql.py in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize)
#     481
#     482     if isinstance(pandas_sql, SQLiteDatabase):
# --> 483         return pandas_sql.read_query(
# ...

# %%
df_tsv1 = pd.read_csv("rt.reviews.tsv.gz" , sep='\t', engine='python')
df_tsv1.head
#WOW
# Out:
# <bound method NDFrame.head of          id                                             review rating   fresh  \
# 0         3  A distinctly gallows take on contemporary fina...    3/5   fresh
# 1         3  It's an allegory in search of a meaning that n...    NaN  rotten
# 2         3  ... life lived in a bubble in financial dealin...    NaN   fresh
# 3         3  Continuing along a line introduced in last yea...    NaN   fresh
# 4         3             ... a perverse twist on neorealism...     NaN   fresh
# ...     ...                                                ...    ...     ...
# 54427  2000  The real charm of this trifle is the deadpan c...    NaN   fresh
# 54428  2000                                                NaN    1/5  rotten
# 54429  2000                                                NaN    2/5  rotten
# 54430  2000                                                NaN  2.5/5  rotten
# 54431  2000                                                NaN    3/5   fresh
#
# ...

# %%
df_tsv2 = pd.read_csv("rt.movie_info.tsv.gz" , sep='\t', engine='python')
df_tsv2.head(10)
# Out:
#    id                                           synopsis rating  \
# 0   1  This gritty, fast-paced, and innovative police...      R
# 1   3  New York City, not-too-distant-future: Eric Pa...      R
# 2   5  Illeana Douglas delivers a superb performance ...      R
# 3   6  Michael Douglas runs afoul of a treacherous su...      R
# 4   7                                                NaN     NR
# 5   8  The year is 1942. As the Allies unite overseas...     PG
# 6  10  Some cast and crew from NBC's highly acclaimed...  PG-13
# 7  13  Stewart Kane, an Irishman living in the Austra...      R
# 8  14  "Love Ranch" is a bittersweet love story that ...      R
# 9  15  When a diamond expedition in the Congo is lost...  PG-13
#
#                                                genre          director  \
# 0                Action and Adventure|Classics|Drama  William Friedkin
# 1                  Drama|Science Fiction and Fantasy  David Cronenberg
# ...
